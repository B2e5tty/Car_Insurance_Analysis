# %% [markdown]
# # Statistical Modeling
#
# Tasks:
# - Data Preparation
# - Model Building
# - Model Evaluation
# - Feature Importance Analysis
# - Use SHAP (SHapley Additive exPlanations) or LIME (Local Interpretable Model-agnostic Explanations) to interpret the model's predictions and understand how individual features influence the outcomes.
# - Report comparison between each model performance.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import os
import sys
sys.path.append(os.path.abspath(os.path.join('..','src')))
from eda import EDA

from scipy.stats import chi2_contingency, ttest_ind, fisher_exact

import warnings
warnings.filterwarnings('ignore')

# %%
# get the CSV file
df_insurance = pd.read_csv("df_insurance.csv")

# instantiate the class
eda = EDA(df_insurance)

# change the datatype to appropriate type
eda.change_dtype()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990010 entries, 0 to 990009
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Gender                    990010 non-null  category
#  1   Province                  990010 non-null  category
#  2   PostalCode                990010 non-null  category
#  3   TransactionMonth          990010 non-null  datetime64[ns]
#  4   VehicleType               990010 non-null  category
#  5   RegistrationYear          990010 non-null  category
#  6   SumInsured                990010 non-null  float64
#  7   TermFrequency             990010 non-null  category
#  8   TotalPremium              990010 non-null  float64
#  9   Product                   990010 non-null  category
#  10  CoverType                 990010 non-null  category
#  11  TotalClaims               990010 non-null  float64
#  12  StatutoryRiskType         990010 non-null  category
#  13  PolicyID                  990010 non-null  object
#  14  Section                   990010 non-null  category
#  15  CalculatedPremiumPerTerm  990010 non-null  float64
# dtypes: category(10), datetime64[ns](1), float64(4), object(1)
# memory usage: 55.7+ MB
# None

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Feature Engineering

# %%
# new features
df_insurance = eda.get_dataframe()

df_insurance['Profit'] = df_insurance['TotalPremium'] - df_insurance['TotalClaims']                            # profit
df_insurance['Premium_per_claims'] = df_insurance['TotalPremium'] / (df_insurance['TotalClaims'] + 1e-6)     # Adding small value to avoid division by zero
df_insurance['RiskScore'] = df_insurance['TotalClaims']  * df_insurance['SumInsured']                        # weighted risk scored
df_insurance['ClaimSeverity'] = df_insurance['TotalClaims'] / df_insurance['SumInsured']                     # The amount claimed relative to the insured value

# %%
# choosing feature to work on 
'''
Gender,
VehicleType,
SumInsured,
TermFrequency,
TotalPremium, 
Product,  
CoverType,
TotalClaims,    
StatutoryRiskType,   
CalculatedPremiumPerTerm,
Profit,     
Premium_per_claims,
RiskScore,
ClaimSeverity
'''
df_insurance = df_insurance[['Gender','VehicleType','SumInsured','TermFrequency','TotalPremium','Product','CoverType','TotalClaims','StatutoryRiskType','CalculatedPremiumPerTerm','Profit','Premium_per_claims','RiskScore','ClaimSeverity']]

eda = EDA(df_insurance)

# %% [markdown]
# A higher SumInsured combined with a higher number of TotalClaims suggests a high-risk policyholder.
# A low TotalClaims with a high SumInsured would indicate a low-risk policyholder.
# The risk score becomes a way to combine the severity (amount insured) with the frequency of claims.

# %% [markdown]
# ### Encoding Categorical Data

# %%
# one-hot encoding
new_df = eda.one_hot()

print(f'Shape of the new dataframe with encoded categories: {new_df.shape}')
# Out:
# Shape of the new dataframe with encoded categories: (990010, 39)

# %%
# check for correlation
correlation = new_df.corr()
# correlation['RiskScore'].sort_values(ascending=False)
correlation
# Out:
#                                                     SumInsured  TotalPremium  \
# SumInsured                                            1.000000     -0.080085
# TotalPremium                                         -0.080085      1.000000
# TotalClaims                                          -0.006895      0.008409
# CalculatedPremiumPerTerm                             -0.120010      0.470701
# Profit                                                0.004587      0.020404
# Premium_per_claims                                   -0.079582      0.996549
# RiskScore                                            -0.004284      0.001450
# ClaimSeverity                                        -0.008287     -0.003039
# Gender_Male                                          -0.005401     -0.029113
# Gender_Not specified                                  0.005304      0.031512
# VehicleType_Heavy Commercial                          0.000520     -0.006612
# VehicleType_Light Commercial                          0.000944      0.000862
# VehicleType_Medium Commercial                         0.001890      0.001357
# VehicleType_Passenger Vehicle                        -0.002193      0.000666
# TermFrequency_Monthly                                -0.068668     -0.004238
# Product_Mobility Commercial Cover: Monthly           -0.010415      0.066284
# Product_Mobility Metered Taxis: Monthly               0.000493     -0.074618
# Product_Standalone Passenger Liability                0.068668      0.004238
# CoverType_Asset Value Preserver                      -0.010739     -0.000005
# CoverType_Baggage/Luggage                            -0.005223     -0.003081
# CoverType_Basic Excess Waiver                        -0.098190      0.070922
# CoverType_Cash Takings                               -0.006834     -0.005141
# CoverType_Cleaning and Removal of Accident Debris    -0.133553     -0.125903
# CoverType_Credit Protection                          -0.029742      0.142838
# CoverType_Deposit Cover                              -0.013516      0.012113
# CoverType_Emergency Charges                          -0.133568     -0.125914
# CoverType_Factory Fitted Sound and Other Electr...   -0.000690     -0.000728
# CoverType_Fire and Theft                             -0.006596      0.028519
# CoverType_Income Protector                           -0.104489      0.066891
# CoverType_Keys and Alarms                            -0.134079     -0.131110
# CoverType_Own Damage                                 -0.089055      0.069974
# CoverType_Passenger Liability                         0.988368     -0.131555
# CoverType_Roadside Assistance                        -0.024277     -0.016985
# CoverType_Signage and Vehicle Wraps                  -0.134470     -0.136302
# CoverType_Standalone passenger liability              0.068668      0.004238
# CoverType_Third Party                                -0.022672      0.492159
# CoverType_Third Party Only                            0.004778      0.009204
# CoverType_Trailer                                    -0.003448     -0.001756
# CoverType_Windscreen                                 -0.135544     -0.079921
#
#                                                     TotalClaims  \
# SumInsured                                            -0.006895
# TotalPremium                                           0.008409
# TotalClaims                                            1.000000
# CalculatedPremiumPerTerm                               0.026253
# Profit                                                -0.999585
# Premium_per_claims                                    -0.011318
# RiskScore                                              0.934181
# ClaimSeverity                                          0.025781
# Gender_Male                                           -0.002851
# Gender_Not specified                                   0.003020
# VehicleType_Heavy Commercial                           0.001351
# VehicleType_Light Commercial                          -0.001296
# VehicleType_Medium Commercial                          0.001200
# VehicleType_Passenger Vehicle                         -0.001175
# TermFrequency_Monthly                                  0.000637
# Product_Mobility Commercial Cover: Monthly            -0.000663
# Product_Mobility Metered Taxis: Monthly                0.000029
# Product_Standalone Passenger Liability                -0.000637
# CoverType_Asset Value Preserver                       -0.000803
# CoverType_Baggage/Luggage                             -0.000358
# CoverType_Basic Excess Waiver                         -0.006757
# CoverType_Cash Takings                                -0.000466
# CoverType_Cleaning and Removal of Accident Debris     -0.009190
# CoverType_Credit Protection                           -0.003025
# CoverType_Deposit Cover                               -0.000469
# CoverType_Emergency Charges                           -0.009168
# CoverType_Factory Fitted Sound and Other Electr...     0.005109
# CoverType_Fire and Theft                              -0.000528
# CoverType_Income Protector                            -0.002770
# CoverType_Keys and Alarms                             -0.009181
# CoverType_Own Damage                                   0.072017
# CoverType_Passenger Liability                         -0.009219
# CoverType_Roadside Assistance                         -0.001626
# CoverType_Signage and Vehicle Wraps                   -0.009191
# CoverType_Standalone passenger liability              -0.000637
# CoverType_Third Party                                 -0.007004
# CoverType_Third Party Only                            -0.000217
# CoverType_Trailer                                     -0.000238
# CoverType_Windscreen                                  -0.007420
#
#                                                     CalculatedPremiumPerTerm  \
# SumInsured                                                         -0.120010
# TotalPremium                                                        0.470701
# TotalClaims                                                         0.026253
# CalculatedPremiumPerTerm                                            1.000000
# Profit                                                             -0.012687
# Premium_per_claims                                                  0.468928
# RiskScore                                                           0.013761
# ClaimSeverity                                                      -0.007796
# Gender_Male                                                        -0.003271
# Gender_Not specified                                                0.004538
# VehicleType_Heavy Commercial                                       -0.000486
# VehicleType_Light Commercial                                       -0.005339
# VehicleType_Medium Commercial                                       0.002180
# VehicleType_Passenger Vehicle                                      -0.000352
# TermFrequency_Monthly                                               0.004011
# Product_Mobility Commercial Cover: Monthly                          0.054485
# Product_Mobility Metered Taxis: Monthly                            -0.059133
# Product_Standalone Passenger Liability                             -0.004011
# CoverType_Asset Value Preserver                                     0.004308
# CoverType_Baggage/Luggage                                          -0.003508
# CoverType_Basic Excess Waiver                                       0.035790
# CoverType_Cash Takings                                             -0.005585
# CoverType_Cleaning and Removal of Accident Debris                  -0.171248
# CoverType_Credit Protection                                         0.139438
# CoverType_Deposit Cover                                             0.012312
# CoverType_Emergency Charges                                        -0.171267
# CoverType_Factory Fitted Sound and Other Electr...                 -0.000959
# CoverType_Fire and Theft                                            0.034949
# CoverType_Income Protector                                          0.028102
# CoverType_Keys and Alarms                                          -0.176377
# CoverType_Own Damage                                                0.469457
# CoverType_Passenger Liability                                      -0.178633
# CoverType_Roadside Assistance                                      -0.022012
# CoverType_Signage and Vehicle Wraps                                -0.181482
# CoverType_Standalone passenger liability                           -0.004011
# CoverType_Third Party                                               0.442096
# CoverType_Third Party Only                                          0.003789
# CoverType_Trailer                                                  -0.002609
# CoverType_Windscreen                                               -0.126958
#
#                                                       Profit  \
# SumInsured                                          0.004587
# TotalPremium                                        0.020404
# TotalClaims                                        -0.999585
# CalculatedPremiumPerTerm                           -0.012687
# Profit                                              1.000000
# Premium_per_claims                                  0.040028
# RiskScore                                          -0.933977
# ClaimSeverity                                      -0.025864
# Gender_Male                                         0.002011
# Gender_Not specified                               -0.002111
# VehicleType_Heavy Commercial                       -0.001541
# VehicleType_Light Commercial                        0.001320
# VehicleType_Medium Commercial                      -0.001161
# VehicleType_Passenger Vehicle                       0.001194
# TermFrequency_Monthly                              -0.000759
# Product_Mobility Commercial Cover: Monthly          0.002573
# Product_Mobility Metered Taxis: Monthly            -0.002179
# Product_Standalone Passenger Liability              0.000759
# CoverType_Asset Value Preserver                     0.000803
# CoverType_Baggage/Luggage                           0.000269
# CoverType_Basic Excess Waiver                       0.008799
# CoverType_Cash Takings                              0.000317
# CoverType_Cleaning and Removal of Accident Debris   0.005561
# CoverType_Credit Protection                         0.007140
# CoverType_Deposit Cover                             0.000817
# CoverType_Emergency Charges                         0.005539
# CoverType_Factory Fitted Sound and Other Electr... -0.005129
# CoverType_Fire and Theft                            0.001350
# CoverType_Income Protector                          0.004697
# CoverType_Keys and Alarms                           0.005402
# CoverType_Own Damage                               -0.069988
# CoverType_Passenger Liability                       0.005427
# CoverType_Roadside Assistance                       0.001137
# CoverType_Signage and Vehicle Wraps                 0.005263
# CoverType_Standalone passenger liability            0.000759
# CoverType_Third Party                               0.021183
# CoverType_Third Party Only                          0.000482
# CoverType_Trailer                                   0.000187
# CoverType_Windscreen                                0.005116
#
#                                                     Premium_per_claims  \
# SumInsured                                                   -0.079582
# TotalPremium                                                  0.996549
# TotalClaims                                                  -0.011318
# CalculatedPremiumPerTerm                                      0.468928
# Profit                                                        0.040028
# Premium_per_claims                                            1.000000
# RiskScore                                                    -0.008382
# ClaimSeverity                                                -0.008647
# Gender_Male                                                  -0.029100
# Gender_Not specified                                          0.031543
# VehicleType_Heavy Commercial                                 -0.006554
# VehicleType_Light Commercial                                  0.000968
# VehicleType_Medium Commercial                                 0.001605
# VehicleType_Passenger Vehicle                                 0.000387
# TermFrequency_Monthly                                        -0.004299
# Product_Mobility Commercial Cover: Monthly                    0.066379
# Product_Mobility Metered Taxis: Monthly                      -0.074728
# Product_Standalone Passenger Liability                        0.004299
# CoverType_Asset Value Preserver                               0.000058
# CoverType_Baggage/Luggage                                    -0.003061
# CoverType_Basic Excess Waiver                                 0.071632
# CoverType_Cash Takings                                       -0.005118
# CoverType_Cleaning and Removal of Accident Debris            -0.125509
# CoverType_Credit Protection                                   0.143426
# CoverType_Deposit Cover                                       0.012176
# CoverType_Emergency Charges                                  -0.125522
# CoverType_Factory Fitted Sound and Other Electr...           -0.000726
# CoverType_Fire and Theft                                      0.028634
# CoverType_Income Protector                                    0.065610
# CoverType_Keys and Alarms                                    -0.130729
# CoverType_Own Damage                                          0.066811
# CoverType_Passenger Liability                                -0.131174
# CoverType_Roadside Assistance                                -0.016905
# CoverType_Signage and Vehicle Wraps                          -0.135935
# CoverType_Standalone passenger liability                      0.004299
# CoverType_Third Party                                         0.493691
# CoverType_Third Party Only                                    0.009244
# CoverType_Trailer                                            -0.001742
# CoverType_Windscreen                                         -0.080188
#
#                                                     RiskScore  ClaimSeverity  \
# SumInsured                                          -0.004284      -0.008287
# TotalPremium                                         0.001450      -0.003039
# TotalClaims                                          0.934181       0.025781
# CalculatedPremiumPerTerm                             0.013761      -0.007796
# Profit                                              -0.933977      -0.025864
# Premium_per_claims                                  -0.008382      -0.008647
# RiskScore                                            1.000000      -0.000416
# ClaimSeverity                                       -0.000416       1.000000
# Gender_Male                                         -0.002404       0.001095
# Gender_Not specified                                 0.002687      -0.001884
# VehicleType_Heavy Commercial                         0.003105       0.004050
# VehicleType_Light Commercial                        -0.000985       0.004679
# VehicleType_Medium Commercial                        0.003297       0.010989
# VehicleType_Passenger Vehicle                       -0.003773      -0.013043
# TermFrequency_Monthly                                0.000471       0.000486
# Product_Mobility Commercial Cover: Monthly          -0.000063      -0.000761
# Product_Mobility Metered Taxis: Monthly             -0.000433       0.000987
# Product_Standalone Passenger Liability              -0.000471      -0.000486
# CoverType_Asset Value Preserver                     -0.000595      -0.000613
# CoverType_Baggage/Luggage                           -0.000265      -0.000273
# CoverType_Basic Excess Waiver                       -0.005004      -0.005162
# CoverType_Cash Takings                              -0.000345      -0.000356
# CoverType_Cleaning and Removal of Accident Debris   -0.006806      -0.007021
# CoverType_Credit Protection                         -0.002348      -0.002700
# CoverType_Deposit Cover                             -0.000641      -0.000752
# CoverType_Emergency Charges                         -0.006806      -0.007022
# CoverType_Factory Fitted Sound and Other Electr...   0.000052      -0.000036
# CoverType_Fire and Theft                            -0.000391      -0.000404
# CoverType_Income Protector                          -0.005216      -0.005488
# CoverType_Keys and Alarms                           -0.006807      -0.007022
# CoverType_Own Damage                                 0.055258      -0.007044
# CoverType_Passenger Liability                       -0.006827      -0.007043
# CoverType_Roadside Assistance                       -0.001222      -0.000368
# CoverType_Signage and Vehicle Wraps                 -0.006807      -0.007022
# CoverType_Standalone passenger liability            -0.000471      -0.000486
# CoverType_Third Party                               -0.003084      -0.007038
# CoverType_Third Party Only                          -0.000160      -0.000165
# CoverType_Trailer                                   -0.000176      -0.000182
# CoverType_Windscreen                                -0.006821       0.060957
#
#                                                     Gender_Male  \
# SumInsured                                            -0.005401
# TotalPremium                                          -0.029113
# TotalClaims                                           -0.002851
# CalculatedPremiumPerTerm                              -0.003271
# Profit                                                 0.002011
# Premium_per_claims                                    -0.029100
# RiskScore                                             -0.002404
# ClaimSeverity                                          0.001095
# Gender_Male                                            1.000000
# Gender_Not specified                                  -0.926053
# VehicleType_Heavy Commercial                          -0.012168
# VehicleType_Light Commercial                          -0.013366
# VehicleType_Medium Commercial                         -0.000455
# VehicleType_Passenger Vehicle                          0.008547
# TermFrequency_Monthly                                 -0.003278
# Product_Mobility Commercial Cover: Monthly            -0.155103
# Product_Mobility Metered Taxis: Monthly                0.159051
# Product_Standalone Passenger Liability                 0.003278
# CoverType_Asset Value Preserver                        0.016737
# CoverType_Baggage/Luggage                             -0.002803
# CoverType_Basic Excess Waiver                         -0.005666
# CoverType_Cash Takings                                 0.023873
# CoverType_Cleaning and Removal of Accident Debris      0.000310
# CoverType_Credit Protection                           -0.009100
# CoverType_Deposit Cover                                0.026861
# CoverType_Emergency Charges                            0.000295
# CoverType_Factory Fitted Sound and Other Electr...    -0.000370
# CoverType_Fire and Theft                              -0.004139
# CoverType_Income Protector                            -0.022008
# CoverType_Keys and Alarms                              0.000295
# CoverType_Own Damage                                  -0.000076
# CoverType_Passenger Liability                         -0.000092
# CoverType_Roadside Assistance                          0.067953
# CoverType_Signage and Vehicle Wraps                    0.000295
# CoverType_Standalone passenger liability               0.003278
# CoverType_Third Party                                  0.000008
# CoverType_Third Party Only                            -0.001696
# CoverType_Trailer                                     -0.001863
# CoverType_Windscreen                                   0.000023
#
#                                                     Gender_Not specified  ...  \
# SumInsured                                                      0.005304  ...
# TotalPremium                                                    0.031512  ...
# TotalClaims                                                     0.003020  ...
# CalculatedPremiumPerTerm                                        0.004538  ...
# Profit                                                         -0.002111  ...
# Premium_per_claims                                              0.031543  ...
# RiskScore                                                       0.002687  ...
# ClaimSeverity                                                  -0.001884  ...
# Gender_Male                                                    -0.926053  ...
# Gender_Not specified                                            1.000000  ...
# VehicleType_Heavy Commercial                                    0.014065  ...
# VehicleType_Light Commercial                                    0.014433  ...
# VehicleType_Medium Commercial                                   0.004287  ...
# VehicleType_Passenger Vehicle                                  -0.013005  ...
# TermFrequency_Monthly                                           0.003115  ...
# Product_Mobility Commercial Cover: Monthly                      0.177536  ...
# Product_Mobility Metered Taxis: Monthly                        -0.181998  ...
# Product_Standalone Passenger Liability                         -0.003115  ...
# CoverType_Asset Value Preserver                                -0.014686  ...
# CoverType_Baggage/Luggage                                       0.003026  ...
# CoverType_Basic Excess Waiver                                   0.010897  ...
# CoverType_Cash Takings                                         -0.021730  ...
# CoverType_Cleaning and Removal of Accident Debris              -0.001182  ...
# CoverType_Credit Protection                                     0.011620  ...
# CoverType_Deposit Cover                                        -0.023920  ...
# CoverType_Emergency Charges                                    -0.001166  ...
# CoverType_Factory Fitted Sound and Other Electr...              0.000400  ...
# CoverType_Fire and Theft                                        0.004469  ...
# CoverType_Income Protector                                      0.025023  ...
# CoverType_Keys and Alarms                                      -0.001166  ...
# CoverType_Own Damage                                           -0.000758  ...
# CoverType_Passenger Liability                                  -0.000745  ...
# CoverType_Roadside Assistance                                  -0.077774  ...
# CoverType_Signage and Vehicle Wraps                            -0.001166  ...
# CoverType_Standalone passenger liability                       -0.003115  ...
# CoverType_Third Party                                          -0.000853  ...
# CoverType_Third Party Only                                      0.001832  ...
# CoverType_Trailer                                               0.002012  ...
# CoverType_Windscreen                                           -0.000870  ...
#
#                                                     CoverType_Keys and Alarms  \
# SumInsured                                                          -0.134079
# TotalPremium                                                        -0.131110
# TotalClaims                                                         -0.009181
# CalculatedPremiumPerTerm                                            -0.176377
# Profit                                                               0.005402
# Premium_per_claims                                                  -0.130729
# RiskScore                                                           -0.006807
# ClaimSeverity                                                       -0.007022
# Gender_Male                                                          0.000295
# Gender_Not specified                                                -0.001166
# VehicleType_Heavy Commercial                                         0.000345
# VehicleType_Light Commercial                                         0.000492
# VehicleType_Medium Commercial                                       -0.000269
# VehicleType_Passenger Vehicle                                       -0.000033
# TermFrequency_Monthly                                                0.007938
# Product_Mobility Commercial Cover: Monthly                          -0.003742
# Product_Mobility Metered Taxis: Monthly                              0.007287
# Product_Standalone Passenger Liability                              -0.007938
# CoverType_Asset Value Preserver                                     -0.010012
# CoverType_Baggage/Luggage                                           -0.004463
# CoverType_Basic Excess Waiver                                       -0.084258
# CoverType_Cash Takings                                              -0.005805
# CoverType_Cleaning and Removal of Accident Debris                   -0.114604
# CoverType_Credit Protection                                         -0.044076
# CoverType_Deposit Cover                                             -0.012271
# CoverType_Emergency Charges                                         -0.114618
# CoverType_Factory Fitted Sound and Other Electr...                  -0.000589
# CoverType_Fire and Theft                                            -0.006590
# CoverType_Income Protector                                          -0.089589
# CoverType_Keys and Alarms                                            1.000000
# CoverType_Own Damage                                                -0.114976
# CoverType_Passenger Liability                                       -0.114962
# CoverType_Roadside Assistance                                       -0.020572
# CoverType_Signage and Vehicle Wraps                                 -0.114618
# CoverType_Standalone passenger liability                            -0.007938
# CoverType_Third Party                                               -0.114873
# CoverType_Third Party Only                                          -0.002701
# CoverType_Trailer                                                   -0.002966
# CoverType_Windscreen                                                -0.114860
#
#                                                     CoverType_Own Damage  \
# SumInsured                                                     -0.089055
# TotalPremium                                                    0.069974
# TotalClaims                                                     0.072017
# CalculatedPremiumPerTerm                                        0.469457
# Profit                                                         -0.069988
# Premium_per_claims                                              0.066811
# RiskScore                                                       0.055258
# ClaimSeverity                                                  -0.007044
# Gender_Male                                                    -0.000076
# Gender_Not specified                                           -0.000758
# VehicleType_Heavy Commercial                                    0.000180
# VehicleType_Light Commercial                                    0.000478
# VehicleType_Medium Commercial                                  -0.000709
# VehicleType_Passenger Vehicle                                   0.000434
# TermFrequency_Monthly                                           0.007963
# Product_Mobility Commercial Cover: Monthly                     -0.010058
# Product_Mobility Metered Taxis: Monthly                         0.006926
# Product_Standalone Passenger Liability                         -0.007963
# CoverType_Asset Value Preserver                                -0.010043
# CoverType_Baggage/Luggage                                      -0.004477
# CoverType_Basic Excess Waiver                                  -0.084522
# CoverType_Cash Takings                                         -0.005823
# CoverType_Cleaning and Removal of Accident Debris              -0.114963
# CoverType_Credit Protection                                    -0.044213
# CoverType_Deposit Cover                                        -0.012310
# CoverType_Emergency Charges                                    -0.114976
# CoverType_Factory Fitted Sound and Other Electr...             -0.000591
# CoverType_Fire and Theft                                       -0.006611
# CoverType_Income Protector                                     -0.089869
# CoverType_Keys and Alarms                                      -0.114976
# CoverType_Own Damage                                            1.000000
# CoverType_Passenger Liability                                  -0.115321
# CoverType_Roadside Assistance                                  -0.020636
# CoverType_Signage and Vehicle Wraps                            -0.114976
# CoverType_Standalone passenger liability                       -0.007963
# CoverType_Third Party                                          -0.115232
# CoverType_Third Party Only                                     -0.002709
# CoverType_Trailer                                              -0.002976
# CoverType_Windscreen                                           -0.115219
#
#                                                     CoverType_Passenger Liability  \
# SumInsured                                                               0.988368
# TotalPremium                                                            -0.131555
# TotalClaims                                                             -0.009219
# CalculatedPremiumPerTerm                                                -0.178633
# Profit                                                                   0.005427
# Premium_per_claims                                                      -0.131174
# RiskScore                                                               -0.006827
# ClaimSeverity                                                           -0.007043
# Gender_Male                                                             -0.000092
# Gender_Not specified                                                    -0.000745
# VehicleType_Heavy Commercial                                             0.000186
# VehicleType_Light Commercial                                             0.000482
# VehicleType_Medium Commercial                                           -0.000705
# VehicleType_Passenger Vehicle                                            0.000427
# TermFrequency_Monthly                                                    0.007962
# Product_Mobility Commercial Cover: Monthly                              -0.009874
# Product_Mobility Metered Taxis: Monthly                                  0.006739
# Product_Standalone Passenger Liability                                  -0.007962
# CoverType_Asset Value Preserver                                         -0.010042
# CoverType_Baggage/Luggage                                               -0.004476
# CoverType_Basic Excess Waiver                                           -0.084511
# CoverType_Cash Takings                                                  -0.005823
# CoverType_Cleaning and Removal of Accident Debris                       -0.114949
# CoverType_Credit Protection                                             -0.044208
# CoverType_Deposit Cover                                                 -0.012308
# CoverType_Emergency Charges                                             -0.114962
# CoverType_Factory Fitted Sound and Other Electr...                      -0.000591
# CoverType_Fire and Theft                                                -0.006610
# CoverType_Income Protector                                              -0.089858
# CoverType_Keys and Alarms                                               -0.114962
# CoverType_Own Damage                                                    -0.115321
# CoverType_Passenger Liability                                            1.000000
# CoverType_Roadside Assistance                                           -0.020634
# CoverType_Signage and Vehicle Wraps                                     -0.114962
# CoverType_Standalone passenger liability                                -0.007962
# CoverType_Third Party                                                   -0.115218
# CoverType_Third Party Only                                              -0.002709
# CoverType_Trailer                                                       -0.002975
# CoverType_Windscreen                                                    -0.115204
#
#                                                     CoverType_Roadside Assistance  \
# SumInsured                                                              -0.024277
# TotalPremium                                                            -0.016985
# TotalClaims                                                             -0.001626
# CalculatedPremiumPerTerm                                                -0.022012
# Profit                                                                   0.001137
# Premium_per_claims                                                      -0.016905
# RiskScore                                                               -0.001222
# ClaimSeverity                                                           -0.000368
# Gender_Male                                                              0.067953
# Gender_Not specified                                                    -0.077774
# VehicleType_Heavy Commercial                                            -0.005274
# VehicleType_Light Commercial                                            -0.000622
# VehicleType_Medium Commercial                                           -0.014593
# VehicleType_Passenger Vehicle                                            0.015430
# TermFrequency_Monthly                                                    0.001425
# Product_Mobility Commercial Cover: Monthly                              -0.204877
# Product_Mobility Metered Taxis: Monthly                                  0.208781
# Product_Standalone Passenger Liability                                  -0.001425
# CoverType_Asset Value Preserver                                         -0.001797
# CoverType_Baggage/Luggage                                               -0.000801
# CoverType_Basic Excess Waiver                                           -0.015123
# CoverType_Cash Takings                                                  -0.001042
# CoverType_Cleaning and Removal of Accident Debris                       -0.020570
# CoverType_Credit Protection                                             -0.007911
# CoverType_Deposit Cover                                                 -0.002203
# CoverType_Emergency Charges                                             -0.020572
# CoverType_Factory Fitted Sound and Other Electr...                      -0.000106
# CoverType_Fire and Theft                                                -0.001183
# CoverType_Income Protector                                              -0.016080
# CoverType_Keys and Alarms                                               -0.020572
# CoverType_Own Damage                                                    -0.020636
# CoverType_Passenger Liability                                           -0.020634
# CoverType_Roadside Assistance                                            1.000000
# CoverType_Signage and Vehicle Wraps                                     -0.020572
# CoverType_Standalone passenger liability                                -0.001425
# CoverType_Third Party                                                   -0.020618
# CoverType_Third Party Only                                              -0.000485
# CoverType_Trailer                                                       -0.000532
# CoverType_Windscreen                                                    -0.020615
#
#                                                     CoverType_Signage and Vehicle Wraps  \
# SumInsured                                                                    -0.134470
# TotalPremium                                                                  -0.136302
# TotalClaims                                                                   -0.009191
# CalculatedPremiumPerTerm                                                      -0.181482
# Profit                                                                         0.005263
# Premium_per_claims                                                            -0.135935
# RiskScore                                                                     -0.006807
# ClaimSeverity                                                                 -0.007022
# Gender_Male                                                                    0.000295
# Gender_Not specified                                                          -0.001166
# VehicleType_Heavy Commercial                                                   0.000345
# VehicleType_Light Commercial                                                   0.000492
# VehicleType_Medium Commercial                                                 -0.000269
# VehicleType_Passenger Vehicle                                                 -0.000033
# TermFrequency_Monthly                                                          0.007938
# Product_Mobility Commercial Cover: Monthly                                    -0.003742
# Product_Mobility Metered Taxis: Monthly                                        0.007287
# Product_Standalone Passenger Liability                                        -0.007938
# CoverType_Asset Value Preserver                                               -0.010012
# CoverType_Baggage/Luggage                                                     -0.004463
# CoverType_Basic Excess Waiver                                                 -0.084258
# CoverType_Cash Takings                                                        -0.005805
# CoverType_Cleaning and Removal of Accident Debris                             -0.114604
# CoverType_Credit Protection                                                   -0.044076
# CoverType_Deposit Cover                                                       -0.012271
# CoverType_Emergency Charges                                                   -0.114618
# CoverType_Factory Fitted Sound and Other Electr...                            -0.000589
# CoverType_Fire and Theft                                                      -0.006590
# CoverType_Income Protector                                                    -0.089589
# CoverType_Keys and Alarms                                                     -0.114618
# CoverType_Own Damage                                                          -0.114976
# CoverType_Passenger Liability                                                 -0.114962
# CoverType_Roadside Assistance                                                 -0.020572
# CoverType_Signage and Vehicle Wraps                                            1.000000
# CoverType_Standalone passenger liability                                      -0.007938
# CoverType_Third Party                                                         -0.114873
# CoverType_Third Party Only                                                    -0.002701
# CoverType_Trailer                                                             -0.002966
# CoverType_Windscreen                                                          -0.114860
#
#                                                     CoverType_Standalone passenger liability  \
# SumInsured                                                                          0.068668
# TotalPremium                                                                        0.004238
# TotalClaims                                                                        -0.000637
# CalculatedPremiumPerTerm                                                           -0.004011
# Profit                                                                              0.000759
# Premium_per_claims                                                                  0.004299
# RiskScore                                                                          -0.000471
# ClaimSeverity                                                                      -0.000486
# Gender_Male                                                                         0.003278
# Gender_Not specified                                                               -0.003115
# VehicleType_Heavy Commercial                                                        0.002969
# VehicleType_Light Commercial                                                        0.002656
# VehicleType_Medium Commercial                                                       0.001393
# VehicleType_Passenger Vehicle                                                      -0.002897
# TermFrequency_Monthly                                                              -1.000000
# Product_Mobility Commercial Cover: Monthly                                         -0.079057
# Product_Mobility Metered Taxis: Monthly                                            -0.006824
# Product_Standalone Passenger Liability                                              1.000000
# CoverType_Asset Value Preserver                                                    -0.000693
# CoverType_Baggage/Luggage                                                          -0.000309
# CoverType_Basic Excess Waiver                                                      -0.005836
# CoverType_Cash Takings                                                             -0.000402
# CoverType_Cleaning and Removal of Accident Debris                                  -0.007937
# CoverType_Credit Protection                                                        -0.003053
# CoverType_Deposit Cover                                                            -0.000850
# CoverType_Emergency Charges                                                        -0.007938
# CoverType_Factory Fitted Sound and Other Electr...                                 -0.000041
# CoverType_Fire and Theft                                                           -0.000456
# CoverType_Income Protector                                                         -0.006205
# CoverType_Keys and Alarms                                                          -0.007938
# CoverType_Own Damage                                                               -0.007963
# CoverType_Passenger Liability                                                      -0.007962
# CoverType_Roadside Assistance                                                      -0.001425
# CoverType_Signage and Vehicle Wraps                                                -0.007938
# CoverType_Standalone passenger liability                                            1.000000
# CoverType_Third Party                                                              -0.007956
# CoverType_Third Party Only                                                         -0.000187
# CoverType_Trailer                                                                  -0.000205
# CoverType_Windscreen                                                               -0.007955
#
#                                                     CoverType_Third Party  \
# SumInsured                                                      -0.022672
# TotalPremium                                                     0.492159
# TotalClaims                                                     -0.007004
# CalculatedPremiumPerTerm                                         0.442096
# Profit                                                           0.021183
# Premium_per_claims                                               0.493691
# RiskScore                                                       -0.003084
# ClaimSeverity                                                   -0.007038
# Gender_Male                                                      0.000008
# Gender_Not specified                                            -0.000853
# VehicleType_Heavy Commercial                                     0.000227
# VehicleType_Light Commercial                                     0.000406
# VehicleType_Medium Commercial                                   -0.000593
# VehicleType_Passenger Vehicle                                    0.000328
# TermFrequency_Monthly                                            0.007956
# Product_Mobility Commercial Cover: Monthly                      -0.003335
# Product_Mobility Metered Taxis: Monthly                          0.006880
# Product_Standalone Passenger Liability                          -0.007956
# CoverType_Asset Value Preserver                                 -0.010034
# CoverType_Baggage/Luggage                                       -0.004473
# CoverType_Basic Excess Waiver                                   -0.084446
# CoverType_Cash Takings                                          -0.005818
# CoverType_Cleaning and Removal of Accident Debris               -0.114860
# CoverType_Credit Protection                                     -0.044174
# CoverType_Deposit Cover                                         -0.012299
# CoverType_Emergency Charges                                     -0.114873
# CoverType_Factory Fitted Sound and Other Electr...              -0.000591
# CoverType_Fire and Theft                                        -0.006605
# CoverType_Income Protector                                      -0.089788
# CoverType_Keys and Alarms                                       -0.114873
# CoverType_Own Damage                                            -0.115232
# CoverType_Passenger Liability                                   -0.115218
# CoverType_Roadside Assistance                                   -0.020618
# CoverType_Signage and Vehicle Wraps                             -0.114873
# CoverType_Standalone passenger liability                        -0.007956
# CoverType_Third Party                                            1.000000
# CoverType_Third Party Only                                      -0.002707
# CoverType_Trailer                                               -0.002973
# CoverType_Windscreen                                            -0.115115
#
#                                                     CoverType_Third Party Only  \
# SumInsured                                                            0.004778
# TotalPremium                                                          0.009204
# TotalClaims                                                          -0.000217
# CalculatedPremiumPerTerm                                              0.003789
# Profit                                                                0.000482
# Premium_per_claims                                                    0.009244
# RiskScore                                                            -0.000160
# ClaimSeverity                                                        -0.000165
# Gender_Male                                                          -0.001696
# Gender_Not specified                                                  0.001832
# VehicleType_Heavy Commercial                                         -0.000692
# VehicleType_Light Commercial                                         -0.000501
# VehicleType_Medium Commercial                                        -0.001916
# VehicleType_Passenger Vehicle                                         0.002131
# TermFrequency_Monthly                                                 0.000187
# Product_Mobility Commercial Cover: Monthly                            0.002366
# Product_Mobility Metered Taxis: Monthly                              -0.002322
# Product_Standalone Passenger Liability                               -0.000187
# CoverType_Asset Value Preserver                                      -0.000236
# CoverType_Baggage/Luggage                                            -0.000105
# CoverType_Basic Excess Waiver                                        -0.001985
# CoverType_Cash Takings                                               -0.000137
# CoverType_Cleaning and Removal of Accident Debris                    -0.002700
# CoverType_Credit Protection                                          -0.001039
# CoverType_Deposit Cover                                              -0.000289
# CoverType_Emergency Charges                                          -0.002701
# CoverType_Factory Fitted Sound and Other Electr...                   -0.000014
# CoverType_Fire and Theft                                             -0.000155
# CoverType_Income Protector                                           -0.002111
# CoverType_Keys and Alarms                                            -0.002701
# CoverType_Own Damage                                                 -0.002709
# CoverType_Passenger Liability                                        -0.002709
# CoverType_Roadside Assistance                                        -0.000485
# CoverType_Signage and Vehicle Wraps                                  -0.002701
# CoverType_Standalone passenger liability                             -0.000187
# CoverType_Third Party                                                -0.002707
# CoverType_Third Party Only                                            1.000000
# CoverType_Trailer                                                    -0.000070
# CoverType_Windscreen                                                 -0.002706
#
#                                                     CoverType_Trailer  \
# SumInsured                                                  -0.003448
# TotalPremium                                                -0.001756
# TotalClaims                                                 -0.000238
# CalculatedPremiumPerTerm                                    -0.002609
# Profit                                                       0.000187
# Premium_per_claims                                          -0.001742
# RiskScore                                                   -0.000176
# ClaimSeverity                                               -0.000182
# Gender_Male                                                 -0.001863
# Gender_Not specified                                         0.002012
# VehicleType_Heavy Commercial                                -0.000760
# VehicleType_Light Commercial                                 0.051003
# VehicleType_Medium Commercial                               -0.002104
# VehicleType_Passenger Vehicle                               -0.010605
# TermFrequency_Monthly                                        0.000205
# Product_Mobility Commercial Cover: Monthly                   0.002599
# Product_Mobility Metered Taxis: Monthly                     -0.002550
# Product_Standalone Passenger Liability                      -0.000205
# CoverType_Asset Value Preserver                             -0.000259
# CoverType_Baggage/Luggage                                   -0.000116
# CoverType_Basic Excess Waiver                               -0.002181
# CoverType_Cash Takings                                      -0.000150
# CoverType_Cleaning and Removal of Accident Debris           -0.002966
# CoverType_Credit Protection                                 -0.001141
# CoverType_Deposit Cover                                     -0.000318
# CoverType_Emergency Charges                                 -0.002966
# CoverType_Factory Fitted Sound and Other Electr...          -0.000015
# CoverType_Fire and Theft                                    -0.000171
# CoverType_Income Protector                                  -0.002319
# CoverType_Keys and Alarms                                   -0.002966
# CoverType_Own Damage                                        -0.002976
# CoverType_Passenger Liability                               -0.002975
# CoverType_Roadside Assistance                               -0.000532
# CoverType_Signage and Vehicle Wraps                         -0.002966
# CoverType_Standalone passenger liability                    -0.000205
# CoverType_Third Party                                       -0.002973
# CoverType_Third Party Only                                  -0.000070
# CoverType_Trailer                                            1.000000
# CoverType_Windscreen                                        -0.002973
#
#                                                     CoverType_Windscreen
# SumInsured                                                     -0.135544
# TotalPremium                                                   -0.079921
# TotalClaims                                                    -0.007420
# CalculatedPremiumPerTerm                                       -0.126958
# Profit                                                          0.005116
# Premium_per_claims                                             -0.080188
# RiskScore                                                      -0.006821
# ClaimSeverity                                                   0.060957
# Gender_Male                                                     0.000023
# Gender_Not specified                                           -0.000870
# VehicleType_Heavy Commercial                                    0.000234
# VehicleType_Light Commercial                                    0.000517
# VehicleType_Medium Commercial                                  -0.000664
# VehicleType_Passenger Vehicle                                   0.000363
# TermFrequency_Monthly                                           0.007955
# Product_Mobility Commercial Cover: Monthly                     -0.009335
# Product_Mobility Metered Taxis: Monthly                         0.006184
# Product_Standalone Passenger Liability                         -0.007955
# CoverType_Asset Value Preserver                                -0.010033
# CoverType_Baggage/Luggage                                      -0.004472
# CoverType_Basic Excess Waiver                                  -0.084436
# CoverType_Cash Takings                                         -0.005817
# CoverType_Cleaning and Removal of Accident Debris              -0.114846
# CoverType_Credit Protection                                    -0.044169
# CoverType_Deposit Cover                                        -0.012297
# CoverType_Emergency Charges                                    -0.114860
# CoverType_Factory Fitted Sound and Other Electr...             -0.000591
# CoverType_Fire and Theft                                       -0.006604
# CoverType_Income Protector                                     -0.089778
# CoverType_Keys and Alarms                                      -0.114860
# CoverType_Own Damage                                           -0.115219
# CoverType_Passenger Liability                                  -0.115204
# CoverType_Roadside Assistance                                  -0.020615
# CoverType_Signage and Vehicle Wraps                            -0.114860
# CoverType_Standalone passenger liability                       -0.007955
# CoverType_Third Party                                          -0.115115
# CoverType_Third Party Only                                     -0.002706
# CoverType_Trailer                                              -0.002973
# CoverType_Windscreen                                            1.000000
#
# [39 rows x 39 columns]

# %% [markdown]
#  **Predicted feature: RiskScore**
#  - Risk score has positive correlation with TotalClaims but negative correlation with Profit, it doesn't show significant relation with other features.
#
#  - Profit has negative correlation with TotalClaims but surprisingly it doesn't have relation with TotalPremium.

# %% [markdown]
# ### Model Building

# %%
# Linear model
print('Linear Model')
eda.linear_model()
# Out:
# Linear Model
# Mean: 5.0416483077470125e+17
# R2: 0.499795575416775

# %%
# Random Forest
print('RandomForest')
eda.ensemble_model()
# Out:
# RandomForest
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Mean: 7.598345059458892e+17
# R2: -0.0019911019279070796

# %%
# Xgboost model
print('xgboost')
eda.xgboost_model()
# Out:
# xgboost
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# Mean: 9.030364935490618e+17
# R2: -0.42043736027503753
